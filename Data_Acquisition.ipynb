# %% [markdown]
# # Acquire Live Event Ticketing Data

# %%
import pandas as pd
import json
import datetime
import requests
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import config
# %matplotlib inline

# %% [markdown]
# ## Acquire Ticketing Data from Ticketmaster

# %%
#DMA and Market numbers
#dma_list = [382,362,264]
mkt_list =  [42,27,14,36,40,22,5,3,31,10,11,35,47,15]

# Function to get the number of pages of ticketmaster data
def get_number_of_TM_pages(market,source='ticketmaster,frontgate',startDate=None,endDate=None):
    url = 'https://app.ticketmaster.com/discovery/v2/events.json?countryCode=US'
    payload = {'source': source,
               'classificationName': 'theatre',
               'size': '200',
               'marketId': market,
               'startDateTime' : startDate,
               'endDateTime' : endDate,
               'apikey': config.tm_key}
    r = requests.get(url,params=payload,verify=True)
    json_obj = json.loads(r.text)
    return json_obj.get('page').get('totalPages')

#Get TicketMaster data, return a dataframe
def getTicketMasterData(pageNumber,market,source='ticketmaster,frontgate',startDate=None,endDate=None):
    url = 'https://app.ticketmaster.com/discovery/v2/events.json?countryCode=US'
    payload = {'source': source,
               'marketId': market,
               'classificationName' : 'theatre',
               'size': '200',
               'page': pageNumber,
               'startDateTime' : startDate,
               'endDateTime' : endDate,
               'apikey': config.tm_key}
    r = requests.get(url,params=payload,verify=True)
    json_response = json.loads(r.text)
    event_info = []
    for event in json_response.get('_embedded',{}).get('events',{}):
         event_info.append({
            'TM_id': str(event.get('id',{})),
            'TM_name' : str(event.get('name',{})),
            'TM_artist': list(str(attraction.get('name')) for attraction in event['_embedded'].get('attractions',{})),
            'TM_venue' : list(str(venue.get('name')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_city' : list(str(venue.get('city',{}).get('name')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_state' : list(str(venue.get('state',{}).get('stateCode')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue _lat' : list(str(venue.get('location',{}).get('latitude')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_long' :list(str(venue.get('location',{}).get('longitude')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_date' : str(event.get('dates',{}).get('start',{}).get('dateTime',{})),
            'TM_timezone' : str(event.get('dates',{}).get('timezone')),
            'TM_span_multiple_days' : str(event.get('dates',{}).get('spanMultipleDays')),
            'TM_presale_date_start' : list(str(presale.get('startDateTime',{})) for presale in event.get('sales').get('presales',{})),
            'TM_presale_date_end' : list(str(presale.get('endDateTime',{})) for presale in event.get('sales').get('presales',{})),
            'TM_sale_date_start' : str(event.get('sales',{}).get('public',{}).get('startDateTime')),
            'TM_FV_prices': event.get('priceRanges'),
            'TM_promoter': str(event.get('promoter',{}).get('name')),
            'TM_genre' : event.get('classifications'),
         })
    tmDF = pd.DataFrame(event_info)
    return tmDF

#Convert timedate information from UTC to local time
def convert_times(df,times_list,tz_col):
    #Loop through each timezone
    df_list = []
    for tz in df[tz_col].unique():
        #Filter rows by timezone
        mask = (df[tz_col] == tz)
        df_local = df.loc[mask]
        #Loop through each datetime row
        for col in times_list:
            #Convert each column to datetime series, localize to UTC and then convert to proper timezone
            df_local[col] = pd.to_datetime(df_local[col],errors='coerce').dt.tz_localize('UTC').dt.tz_convert(tz)
            #Convert each column to datetime series, localize to UTC and then convert to proper timezone
        df_list.append(df_local)
    df = pd.concat(df_list, axis=0)
    return df

#Explode out columns with nested information
def explode(df,col,index_col):
    df1 = df[col].apply(pd.Series)
    df1 = df1[0].apply(pd.Series)
    df1.index = df[index_col]
    df = df.merge(df1, how='left', left_on=index_col, right_index=True)
    df = df.drop(col,axis=1)
    return df

# %%
#Create list US Ticketmaster market numbers -- Look at TM API docs for market number info.
#mkt_list = [40] # 40 is San Antonio and Austin Market

# %% [markdown]
# **Ticketmaster API limits the amount of data that can be pulled per day**
# - Initial Data Acquisition is returning:
#     - Concert events in market 40 (San Antonio & Austin)
#     - Occuring between the dates April 1, 2021 and May 1, 2021

# %%
tm_df_list = []
p1startDate = '2018-01-01T00:00:00Z'
p1endDate = '2020-03-31T00:00:00Z'

#Create dictionaries of dma/mkt numbers, and number of pages of data
mkt_dict_p1 = dict()
mkt_dict_p2 =dict()

#Get number of pages for face value market items
for mkt in mkt_list:
    mkt_dict_p1[mkt] = get_number_of_TM_pages(market = mkt,
                                              startDate = p1startDate,
                                              endDate = p1endDate)
    mkt_dict_p2[mkt] = get_number_of_TM_pages(market = mkt,
                                              startDate = p1endDate)
    
#Get market data
for mkt in mkt_dict_p1.keys():
    for current_page in range(0,mkt_dict_p1[mkt]):
        tm_df_list.append(getTicketMasterData(market = mkt,
                                              pageNumber = current_page,
                                              startDate = p1startDate,
                                              endDate = p1endDate))
for mkt in mkt_dict_p2.keys():
    for current_page in range(0,mkt_dict_p2[mkt]):
        tm_df_list.append(getTicketMasterData(market = mkt,
                                              pageNumber = current_page,
                                              startDate = p1endDate))

# %%
#Combine all dataframes for full data on events and face_value prices
tm_df = pd.concat(tm_df_list,axis=0)

tm_df.head()
# Out:
#             TM_id                                            TM_name  \
# 0  vvG1HZptU9av1x  Disney Princess: The Concert Brought to you by...
# 1  vvG1HZpAEWqUaC                                Anastasia (Touring)
# 2  vvG1HZpAEWQJa7                                Anastasia (Touring)
# 3  vvG1HZpAEWqkaG                                Anastasia (Touring)
# 4  vvG1HZpAEWjpaF                                Anastasia (Touring)
#
#                         TM_artist           TM_venue TM_venue_city  \
# 0  [Disney Princess: The Concert]  Paramount Theatre       Seattle
# 1           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 2           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 3           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 4           [Anastasia (Touring)]  Paramount Theatre       Seattle
#
#   TM_venue_state TM_venue _lat TM_venue_long               TM_date  \
# 0             WA    47.6135664  -122.3319103  2022-03-06T22:00:00Z
# 1             WA    47.6135664  -122.3319103  2022-01-30T04:00:00Z
# 2             WA    47.6135664  -122.3319103  2022-01-26T03:30:00Z
# 3             WA    47.6135664  -122.3319103  2022-01-29T04:00:00Z
# 4             WA    47.6135664  -122.3319103  2022-01-28T03:30:00Z
#
#            TM_timezone TM_span_multiple_days  \
# 0  America/Los_Angeles                 False
# 1  America/Los_Angeles                 False
# 2  America/Los_Angeles                 False
# 3  America/Los_Angeles                 False
# 4  America/Los_Angeles                 False
#
#                                TM_presale_date_start  \
# 0  [2021-05-04T14:00:00Z, 2021-05-06T17:00:00Z, 2...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                  TM_presale_date_end    TM_sale_date_start  \
# 0  [2021-05-07T05:00:00Z, 2021-05-07T05:00:00Z, 2...  2021-05-07T17:00:00Z
# 1                                                 []  2020-03-09T17:00:00Z
# 2                                                 []  2020-03-09T17:00:00Z
# 3                                                 []  2020-03-09T17:00:00Z
# 4                                                 []  2020-03-09T17:00:00Z
#
#                                         TM_FV_prices        TM_promoter  \
# 0  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 1  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 2  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 3  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 4  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
#
#                                             TM_genre
# 0  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 2  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 4  [{'primary': True, 'segment': {'id': 'KZFzniwn...

# %%
tm_df.shape
# Out:
# (4452, 17)

# %% [markdown]
# ## Initial Data Preparation

# %% [markdown]
# **Events with same name but different dates and markets have the same TM_id. I am dropping duplicates for this initial analysis.**<br>
# **Also dropping all parking related ticket sales**

# %%
#Drop duplicates
tm_df.drop_duplicates(subset='TM_id',inplace=True)

#Remove parking passes
tm_df = tm_df.loc[~tm_df['TM_venue'].str.lower().str.contains('parking')]
tm_df = tm_df.loc[~tm_df['TM_name'].str.lower().str.contains('parking')]

# %% [markdown]
# **Expanding out the price column, genre columnm, and ID column**

# %%
#Explode price column
tm_df = explode(tm_df,col='TM_FV_prices',index_col='TM_id')
#Unnest genre info and clean up data in exploded columns
tm_df = explode(tm_df,'TM_genre','TM_id')
for col in ['genre','segment','subGenre']:
    tm_df[col] = tm_df[col].map(lambda x: dict(x).get('name',{}))
tm_df.head()
# Out:
#             TM_id                                            TM_name  \
# 0  vvG1HZptU9av1x  Disney Princess: The Concert Brought to you by...
# 1  vvG1HZpAEWqUaC                                Anastasia (Touring)
# 2  vvG1HZpAEWQJa7                                Anastasia (Touring)
# 3  vvG1HZpAEWqkaG                                Anastasia (Touring)
# 4  vvG1HZpAEWjpaF                                Anastasia (Touring)
#
#                         TM_artist           TM_venue TM_venue_city  \
# 0  [Disney Princess: The Concert]  Paramount Theatre       Seattle
# 1           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 2           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 3           [Anastasia (Touring)]  Paramount Theatre       Seattle
# 4           [Anastasia (Touring)]  Paramount Theatre       Seattle
#
#   TM_venue_state TM_venue _lat TM_venue_long               TM_date  \
# 0             WA    47.6135664  -122.3319103  2022-03-06T22:00:00Z
# 1             WA    47.6135664  -122.3319103  2022-01-30T04:00:00Z
# 2             WA    47.6135664  -122.3319103  2022-01-26T03:30:00Z
# 3             WA    47.6135664  -122.3319103  2022-01-29T04:00:00Z
# 4             WA    47.6135664  -122.3319103  2022-01-28T03:30:00Z
#
#            TM_timezone  ...     max    min    type_x primary         segment  \
# 0  America/Los_Angeles  ...   75.25  35.25  standard    True  Arts & Theatre
# 1  America/Los_Angeles  ...  130.00  50.00  standard    True  Arts & Theatre
# 2  America/Los_Angeles  ...  130.00  35.00  standard    True  Arts & Theatre
# 3  America/Los_Angeles  ...  130.00  50.00  standard    True  Arts & Theatre
# 4  America/Los_Angeles  ...  130.00  35.00  standard    True  Arts & Theatre
#
#                 genre            subGenre  \
# 0  Children's Theatre  Children's Theatre
# 1             Theatre             Musical
# 2             Theatre             Musical
# 3             Theatre             Musical
# 4             Theatre             Musical
#
#                                            type_y  \
# 0  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 1  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 2  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 3  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 4  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
#
#                                              subType family
# 0  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 1  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 2  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 3  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 4  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
#
# [5 rows x 27 columns]

# %%
tm_df.shape
# Out:
# (4416, 27)

# %%
tm_df.tail(20)
# Out:
#              TM_id                                            TM_name  \
# 75  vvG1VZpI9AEyyX  Dance Now! Miami: Program III featuring Dorian...
# 76  vvG1VZpP5AY_rH         Cuban Classical Ballet of Miami Grand Gala
# 77  vvG1VZp_Qc_F5U                                           Shen Yun
# 78  vvG1VZpA58w1Z9                               South Florida Ballet
# 79  vvG1VZpI5prnKN        State Ballet Theatre of Ukraine: Cinderella
# 80  vvG1VZ4gwI6581                            Alan Chamo: M1ND H4CK3R
# 81  vvG1VZptrs0ndP                      Miss Universe Dress Rehearsal
# 82  vvG1VZ4gwI6D88                            Alan Chamo: M1ND H4CK3R
# 83  vvG1VZp7QuwnS7                                       Kevin Nealon
# 84  vvG1VZpCnmwAPd                          Ronald K. Brown: EVIDENCE
# 85  vvG1VZpEL8gtHc                               South Florida Ballet
# 86  vvG1VZpCnWJgIo                       Pilobolous: The Big Five-OH!
# 87  vvG1VZpCnWJPET                       Pilobolous: The Big Five-OH!
# 88  vvG1VZpCnmsg0B                          Ronald K. Brown: EVIDENCE
# 89  vvG1VZpIM4etH-                                         Tango Fire
# 90  vvG1VZp_MtPbhg                            Catapult: Magic Shadows
# 91  vvG1VZpxDbIIxt  Wild World of Animals starring Grant Kemmerer ...
# 92  vvG1VZpxDbtbNC  Wild World of Animals starring Grant Kemmerer ...
# 93  vvG1VZp_Mt0bhS                            Catapult: Magic Shadows
# 94  vvG1VZpaUqY_oM                 Santino Fontana with Seth Rudetsky
#
#                             TM_artist  \
# 75                       [Dance Now!]
# 76  [Cuban Classical Ballet of Miami]
# 77                         [Shen Yun]
# 78     [South Florida Ballet Theater]
# 79                                 []
# 80                       [Alan Chamo]
# 81                    [Miss Universe]
# 82                       [Alan Chamo]
# 83                     [Kevin Nealon]
# 84                   [Ronald K Brown]
# 85     [South Florida Ballet Theater]
# 86          [Pilobolus Dance Theater]
# 87          [Pilobolus Dance Theater]
# 88                   [Ronald K Brown]
# 89                       [Tango Fire]
# 90           [catapult entertainment]
# 91                                 []
# 92                                 []
# 93           [catapult entertainment]
# 94   [Santino Fontana, Seth Rudetsky]
#
#                                              TM_venue  TM_venue_city  \
# 75                  Amaturo Theater at Broward Center  Ft Lauderdale
# 76  The Fillmore Miami Beach at Jackie Gleason The...    Miami Beach
# 77              Au-Rene Theater at the Broward Center  Ft Lauderdale
# 78                  Amaturo Theater at Broward Center  Ft Lauderdale
# 79                                   Parker Playhouse  Ft Lauderdale
# 80          Abdo New River Room at the Broward Center  Ft Lauderdale
# 81                                     Hard Rock Live      Hollywood
# 82          Abdo New River Room at the Broward Center  Ft Lauderdale
# 83                  Amaturo Theater at Broward Center  Ft Lauderdale
# 84                  Amaturo Theater at Broward Center  Ft Lauderdale
# 85                  Amaturo Theater at Broward Center  Ft Lauderdale
# 86                  Amaturo Theater at Broward Center  Ft Lauderdale
# 87                  Amaturo Theater at Broward Center  Ft Lauderdale
# 88                  Amaturo Theater at Broward Center  Ft Lauderdale
# 89                                   Parker Playhouse  Ft Lauderdale
# 90                    Aventura Arts & Cultural Center       Aventura
# 91                    Aventura Arts & Cultural Center       Aventura
# 92                    Aventura Arts & Cultural Center       Aventura
# 93                    Aventura Arts & Cultural Center       Aventura
# 94                                   Parker Playhouse  Ft Lauderdale
#
#    TM_venue_state TM_venue _lat TM_venue_long               TM_date  \
# 75             FL       26.1193    -80.149426  2021-05-16T00:00:00Z
# 76             FL     25.792917     -80.13314  2021-06-06T00:00:00Z
# 77             FL       26.1193    -80.149426  2021-07-18T18:00:00Z
# 78             FL       26.1193    -80.149426  2021-11-27T00:00:00Z
# 79             FL     26.134246    -80.136172  2021-12-30T00:00:00Z
# 80             FL       26.1193    -80.149426  2021-11-06T00:00:00Z
# 81             FL    26.0503384   -80.2109577  2021-05-16T17:00:00Z
# 82             FL       26.1193    -80.149426  2021-11-07T00:00:00Z
# 83             FL       26.1193    -80.149426  2022-03-13T01:00:00Z
# 84             FL       26.1193    -80.149426  2022-01-07T01:00:00Z
# 85             FL       26.1193    -80.149426  2021-11-26T19:00:00Z
# 86             FL       26.1193    -80.149426  2022-02-26T00:30:00Z
# 87             FL       26.1193    -80.149426  2022-02-25T00:30:00Z
# 88             FL       26.1193    -80.149426  2022-01-06T01:00:00Z
# 89             FL     26.134246    -80.136172  2022-01-30T23:00:00Z
# 90             FL   25.94960232  -80.13458177  2022-02-27T00:00:00Z
# 91             FL   25.94960232  -80.13458177  2022-02-12T16:00:00Z
# 92             FL   25.94960232  -80.13458177  2022-02-12T19:00:00Z
# 93             FL   25.94960232  -80.13458177  2022-02-26T19:00:00Z
# 94             FL     26.134246    -80.136172  2022-02-06T01:00:00Z
#
#          TM_timezone  ...     max    min    type_x primary         segment  \
# 75  America/New_York  ...   40.00  40.00  standard    True  Arts & Theatre
# 76  America/New_York  ...   59.00  39.00  standard    True  Arts & Theatre
# 77  America/New_York  ...  200.00  80.00  standard    True  Arts & Theatre
# 78  America/New_York  ...   46.73  23.36  standard    True  Arts & Theatre
# 79  America/New_York  ...   65.88  36.16  standard    True  Arts & Theatre
# 80  America/New_York  ...   45.00  35.00  standard    True  Arts & Theatre
# 81  America/New_York  ...  187.00  80.00  standard    True  Arts & Theatre
# 82  America/New_York  ...   45.00  35.00  standard    True  Arts & Theatre
# 83  America/New_York  ...   45.00  45.00  standard    True  Arts & Theatre
# 84  America/New_York  ...   59.50  49.50  standard    True  Arts & Theatre
# 85  America/New_York  ...   50.00  25.00  standard    True  Arts & Theatre
# 86  America/New_York  ...   65.00  55.00  standard    True  Arts & Theatre
# 87  America/New_York  ...   65.00  55.00  standard    True  Arts & Theatre
# 88  America/New_York  ...   59.50  49.50  standard    True  Arts & Theatre
# 89  America/New_York  ...   73.00  43.00  standard    True  Arts & Theatre
# 90  America/New_York  ...   40.00  35.00  standard    True  Arts & Theatre
# 91  America/New_York  ...   35.00  35.00  standard    True  Arts & Theatre
# 92  America/New_York  ...   35.00  35.00  standard    True  Arts & Theatre
# 93  America/New_York  ...   40.00  35.00  standard    True  Arts & Theatre
# 94  America/New_York  ...   67.00  37.00  standard    True           Music
#
#                genre         subGenre  \
# 75             Dance            Dance
# 76             Dance            Dance
# 77             Dance            Dance
# 78             Dance            Dance
# 79             Dance            Dance
# 80  Magic & Illusion            Magic
# 81           Fashion          Fashion
# 82  Magic & Illusion            Magic
# 83            Comedy           Comedy
# 84             Dance            Dance
# 85             Dance            Dance
# 86             Dance            Dance
# 87             Dance            Dance
# 88             Dance            Dance
# 89             Dance            Dance
# 90   Performance Art  Performance Art
# 91           Variety          Variety
# 92           Variety          Variety
# 93   Performance Art  Performance Art
# 94             Other            Other
#
#                                             type_y  \
# 75  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 76  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 77  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 78  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 79  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 80  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 81  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 82  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 83  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 84  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 85  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 86  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 87  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 88  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 89  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 90  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 91  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 92  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 93  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 94  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
#
#                                               subType family
# 75  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 76  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 77  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 78  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 79  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 80  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 81  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 82  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 83  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 84  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 85  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 86  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 87  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 88  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 89  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 90  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 91  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 92  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 93  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 94  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
#
# [20 rows x 27 columns]

# %%
#tm_df.to_csv('theatre_tm_events_050121_123122.csv')

# %%
#tm_df[tm_df.TM_venue_state == "TX"]
