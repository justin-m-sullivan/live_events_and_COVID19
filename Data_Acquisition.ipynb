# %% [markdown]
# # Acquire Live Event Ticketing Data

# %%
import pandas as pd
import json
import datetime
import requests
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import config
# %matplotlib inline

# %% [markdown]
# ## Acquire Ticketing Data from Ticketmaster

# %%
#DMA and Market numbers
#dma_list = [382,362,264]
#mkt_list =  [42,27,14,36,40,22,5,3,31,10,11,35,47,15]

# Function to get the number of pages of ticketmaster data
def get_number_of_TM_pages(market,source='ticketmaster,frontgate',startDate=None,endDate=None):
    url = 'https://app.ticketmaster.com/discovery/v2/events.json?countryCode=US'
    payload = {'source': source,
               'classificationName': 'music',
               'size': '200',
               'marketId': market,
               'startDateTime' : startDate,
               'endDateTime' : endDate,
               'apikey': config.tm_key}
    r = requests.get(url,params=payload,verify=True)
    json_obj = json.loads(r.text)
    return json_obj.get('page').get('totalPages')

#Get TicketMaster data, return a dataframe
def getTicketMasterData(pageNumber,market,source='ticketmaster,frontgate',startDate=None,endDate=None):
    url = 'https://app.ticketmaster.com/discovery/v2/events.json?countryCode=US'
    payload = {'source': source,
               'marketId': market,
               'classificationName' : 'music',
               'size': '200',
               'page': pageNumber,
               'startDateTime' : startDate,
               'endDateTime' : endDate,
               'apikey': config.tm_key}
    r = requests.get(url,params=payload,verify=True)
    json_response = json.loads(r.text)
    event_info = []
    for event in json_response.get('_embedded',{}).get('events',{}):
         event_info.append({
            'TM_id': str(event.get('id',{})),
            'TM_name' : str(event.get('name',{})),
            'TM_artist': list(str(attraction.get('name')) for attraction in event['_embedded'].get('attractions',{})),
            'TM_venue' : list(str(venue.get('name')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_city' : list(str(venue.get('city',{}).get('name')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_state' : list(str(venue.get('state',{}).get('stateCode')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue _lat' : list(str(venue.get('location',{}).get('latitude')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_venue_long' :list(str(venue.get('location',{}).get('longitude')) for venue in event['_embedded'].get('venues',{}))[0],
            'TM_date' : str(event.get('dates',{}).get('start',{}).get('dateTime',{})),
            'TM_timezone' : str(event.get('dates',{}).get('timezone')),
            'TM_span_multiple_days' : str(event.get('dates',{}).get('spanMultipleDays')),
            'TM_presale_date_start' : list(str(presale.get('startDateTime',{})) for presale in event.get('sales').get('presales',{})),
            'TM_presale_date_end' : list(str(presale.get('endDateTime',{})) for presale in event.get('sales').get('presales',{})),
            'TM_sale_date_start' : str(event.get('sales',{}).get('public',{}).get('startDateTime')),
            'TM_FV_prices': event.get('priceRanges'),
            'TM_promoter': str(event.get('promoter',{}).get('name')),
            'TM_genre' : event.get('classifications'),
         })
    tmDF = pd.DataFrame(event_info)
    return tmDF

#Convert timedate information from UTC to local time
def convert_times(df,times_list,tz_col):
    #Loop through each timezone
    df_list = []
    for tz in df[tz_col].unique():
        #Filter rows by timezone
        mask = (df[tz_col] == tz)
        df_local = df.loc[mask]
        #Loop through each datetime row
        for col in times_list:
            #Convert each column to datetime series, localize to UTC and then convert to proper timezone
            df_local[col] = pd.to_datetime(df_local[col],errors='coerce').dt.tz_localize('UTC').dt.tz_convert(tz)
            #Convert each column to datetime series, localize to UTC and then convert to proper timezone
        df_list.append(df_local)
    df = pd.concat(df_list, axis=0)
    return df

#Explode out columns with nested information
def explode(df,col,index_col):
    df1 = df[col].apply(pd.Series)
    df1 = df1[0].apply(pd.Series)
    df1.index = df[index_col]
    df = df.merge(df1, how='left', left_on=index_col, right_index=True)
    df = df.drop(col,axis=1)
    return df

# %%
#Create list US Ticketmaster market numbers -- Look at TM API docs for market number info.
mkt_list = [40] # 40 is San Antonio and Austin Market

# %% [markdown]
# **Ticketmaster API limits the amount of data that can be pulled per day**
# - Initial Data Acquisition is returning:
#     - Concert events in market 40 (San Antonio & Austin)
#     - Occuring between the dates April 1, 2021 and May 1, 2021

# %%
tm_df_list = []
p1startDate = '2021-04-01T00:00:00Z'
p1endDate = '2021-05-01T00:00:00Z'

#Create dictionaries of dma/mkt numbers, and number of pages of data
mkt_dict_p1 = dict()
mkt_dict_p2 =dict()

#Get number of pages for face value market items
for mkt in mkt_list:
    mkt_dict_p1[mkt] = get_number_of_TM_pages(market = mkt,
                                              startDate = p1startDate,
                                              endDate = p1endDate)
    mkt_dict_p2[mkt] = get_number_of_TM_pages(market = mkt,
                                              startDate = p1endDate)
    
#Get market data
for mkt in mkt_dict_p1.keys():
    for current_page in range(0,mkt_dict_p1[mkt]):
        tm_df_list.append(getTicketMasterData(market = mkt,
                                              pageNumber = current_page,
                                              startDate = p1startDate,
                                              endDate = p1endDate))
for mkt in mkt_dict_p2.keys():
    for current_page in range(0,mkt_dict_p2[mkt]):
        tm_df_list.append(getTicketMasterData(market = mkt,
                                              pageNumber = current_page,
                                              startDate = p1endDate))

# %%
#Combine all dataframes for full data on events and face_value prices
tm_df = pd.concat(tm_df_list,axis=0)

tm_df.head()
# Out:
#            TM_id                                            TM_name  \
# 0  G5dIZp0wKy-SF  Justin Furstenfeld of Blue October (21+ Event)...
# 1  G5dIZpbCwKv7f  Jamestown Revival (21+ Event) (Reduced Capacit...
# 2  G5dIZ4URqF9t2                                        The Monkees
# 3  G5dIZpELxbwy-                                        Jackopierce
# 4  G5dIZpeE09UbK                                        Jackopierce
#
#               TM_artist                                      TM_venue  \
# 0  [Justin Furstenfeld]                       Whitewater Amphitheater
# 1   [Jamestown Revival]                       Whitewater Amphitheater
# 2         [The Monkees]  Austin City Limits Live at The Moody Theater
# 3         [Jackopierce]  Austin City Limits Live at The Moody Theater
# 4         [Jackopierce]  Austin City Limits Live at The Moody Theater
#
#    TM_venue_city TM_venue_state TM_venue _lat TM_venue_long  \
# 0  New Braunfels             TX     29.862013    -98.156969
# 1  New Braunfels             TX     29.862013    -98.156969
# 2         Austin             TX   30.26536691   -97.7471222
# 3         Austin             TX   30.26536691   -97.7471222
# 4         Austin             TX   30.26536691   -97.7471222
#
#                 TM_date      TM_timezone TM_span_multiple_days  \
# 0  2021-04-24T01:00:00Z  America/Chicago                 False
# 1  2021-04-04T01:00:00Z  America/Chicago                 False
# 2  2021-04-03T01:00:00Z  America/Chicago                 False
# 3  2021-04-12T01:00:00Z  America/Chicago                 False
# 4  2021-04-12T01:00:00Z  America/Chicago                 False
#
#     TM_presale_date_start     TM_presale_date_end    TM_sale_date_start  \
# 0                      []                      []  2021-02-19T16:00:00Z
# 1                      []                      []  2020-12-11T16:00:00Z
# 2                      []                      []  2019-11-15T16:00:00Z
# 3                      []                      []  2021-03-24T19:00:00Z
# 4  [2020-01-16T16:00:00Z]  [2020-01-17T04:00:00Z]  2020-01-17T16:00:00Z
#
#                                         TM_FV_prices        TM_promoter  \
# 0  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 1  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 2  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 3  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
# 4  [{'type': 'standard', 'currency': 'USD', 'min'...  PROMOTED BY VENUE
#
#                                             TM_genre
# 0  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 2  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 4  [{'primary': True, 'segment': {'id': 'KZFzniwn...

# %% [markdown]
# ## Initial Data Preparation

# %% [markdown]
# **Events with same name but different dates and markets have the same TM_id. I am dropping duplicates for this initial analysis.**<br>
# **Also dropping all parking related ticket sales**

# %%
#Drop duplicates
tm_df.drop_duplicates(subset='TM_id',inplace=True)

#Remove parking passes
tm_df = tm_df.loc[~tm_df['TM_venue'].str.lower().str.contains('parking')]
tm_df = tm_df.loc[~tm_df['TM_name'].str.lower().str.contains('parking')]

# %% [markdown]
# **Expanding out the price column, genre columnm, and ID column**

# %%
#Explode price column
tm_df = explode(tm_df,col='TM_FV_prices',index_col='TM_id')
#Unnest genre info and clean up data in exploded columns
tm_df = explode(tm_df,'TM_genre','TM_id')
for col in ['genre','segment','subGenre']:
    tm_df[col] = tm_df[col].map(lambda x: dict(x).get('name',{}))
tm_df.head()
# Out:
#            TM_id                                            TM_name  \
# 0  G5dIZp0wKy-SF  Justin Furstenfeld of Blue October (21+ Event)...
# 1  G5dIZpbCwKv7f  Jamestown Revival (21+ Event) (Reduced Capacit...
# 2  G5dIZ4URqF9t2                                        The Monkees
# 3  G5dIZpELxbwy-                                        Jackopierce
# 4  G5dIZpeE09UbK                                        Jackopierce
#
#               TM_artist                                      TM_venue  \
# 0  [Justin Furstenfeld]                       Whitewater Amphitheater
# 1   [Jamestown Revival]                       Whitewater Amphitheater
# 2         [The Monkees]  Austin City Limits Live at The Moody Theater
# 3         [Jackopierce]  Austin City Limits Live at The Moody Theater
# 4         [Jackopierce]  Austin City Limits Live at The Moody Theater
#
#    TM_venue_city TM_venue_state TM_venue _lat TM_venue_long  \
# 0  New Braunfels             TX     29.862013    -98.156969
# 1  New Braunfels             TX     29.862013    -98.156969
# 2         Austin             TX   30.26536691   -97.7471222
# 3         Austin             TX   30.26536691   -97.7471222
# 4         Austin             TX   30.26536691   -97.7471222
#
#                 TM_date      TM_timezone  ...     max    min    type_x  \
# 0  2021-04-24T01:00:00Z  America/Chicago  ...  102.00  43.00  standard
# 1  2021-04-04T01:00:00Z  America/Chicago  ...   45.00  23.00  standard
# 2  2021-04-03T01:00:00Z  America/Chicago  ...   80.75  40.75  standard
# 3  2021-04-12T01:00:00Z  America/Chicago  ...   30.00  25.00  standard
# 4  2021-04-12T01:00:00Z  America/Chicago  ...   25.00  25.00  standard
#
#   primary segment  genre          subGenre  \
# 0    True   Music   Rock               Pop
# 1    True   Music   Rock  Alternative Rock
# 2    True   Music   Rock               Pop
# 3    True   Music   Rock               Pop
# 4    True   Music   Rock               Pop
#
#                                            type_y  \
# 0  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 1  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 2  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 3  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 4  {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
#
#                                              subType family
# 0  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 1  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 2  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 3  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 4  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
#
# [5 rows x 27 columns]

# %%
tm_df.shape
# Out:
# (105, 27)

# %%
tm_df.sample(20)
# Out:
#             TM_id                                            TM_name  \
# 75  G5dIZpkEOs0DN                           Celtic Thunder - Ireland
# 57  G5dIZ4gBvkwAd                                          Buddy Guy
# 35  G5dIZ4UUfFwoR                                        Keith Sweat
# 12  G5dIZp7Mm0Mtn                        PRIMUS - A Tribute to Kings
# 3   G5dIZ4Ml6IKRh  Alanis Morissette w/special guest Garbage & al...
# 3   G5dIZpELxbwy-                                        Jackopierce
# 54  G5dIZpA3cP7gV                 Judas Priest: 50 Heavy Metal Years
# 64  G5dIZpA9IcEPy                                    Smokey Robinson
# 27  G5dIZp7R4Y4tt                        Widespread Panic 3-Day Pass
# 10  G5dIZp7QVaMxP                      Jason Isbell and the 400 Unit
# 25  G5dIZ4UktspkF  David Gray - White Ladder:The 20th Anniversary...
# 69  G5dIZpxDlOS16  Jon Wolfe (21+ Event) (Reduced Capacity, Socia...
# 52  G5dIZ4zKfvA-1                              No Limit Reunion Tour
# 28  G5dIZ4UkyBk-R          Geoff Tate's Empire 30th Anniversary Tour
# 44  G5dIZ4MK_2PpG  Willie Nelson & Family with Special Guest Pat ...
# 81  G5dIZ4gxuEdwS    Austin City Limits Music Festival - Weekend Two
# 74  G5dIZpeCjKKnz                                 Rebirth Brass Band
# 47  G5dIZpE1xIeOu                                The Texas Gentlemen
# 26  G5dIZpelJUJzQ       Ministry with Helmet and Front Line Assembly
# 2   G5dIZ4URqF9t2                                        The Monkees
#
#                                             TM_artist  \
# 75                                   [Celtic Thunder]
# 57                                        [Buddy Guy]
# 35                      [Keith Sweat, SWV, All-4-One]
# 12                    [Primus, Wolfmother, The Sword]
# 3             [Alanis Morissette, Garbage, Liz Phair]
# 3                                       [Jackopierce]
# 54                            [Judas Priest, Sabaton]
# 64                                  [Smokey Robinson]
# 27                                 [Widespread Panic]
# 10  [Jason Isbell and the 400 Unit, Lucinda Williams]
# 25                                       [David Gray]
# 69                            [Jon Wolfe, Kylie Frey]
# 52  [Master P, Silkk the Shocker, Fiend, Mystikal,...
# 28                [Geoff Tate, Till Death Do Us Part]
# 44                         [Willie Nelson, Pat Green]
# 81                [Austin City Limits Music Festival]
# 74                               [Rebirth Brass Band]
# 47                              [The Texas Gentlemen]
# 26            [Ministry, Front Line Assembly, Helmet]
# 2                                       [The Monkees]
#
#                                         TM_venue  TM_venue_city  \
# 75                  Majestic Theatre San Antonio    San Antonio
# 57  Austin City Limits Live at The Moody Theater         Austin
# 35                    H-E-B Center at Cedar Park     Cedar Park
# 12  Austin City Limits Live at The Moody Theater         Austin
# 3                Germania Insurance Amphitheater         Austin
# 3   Austin City Limits Live at The Moody Theater         Austin
# 54                              Freeman Coliseum    San Antonio
# 64                    H-E-B Center at Cedar Park     Cedar Park
# 27  Austin City Limits Live at The Moody Theater         Austin
# 10  Austin City Limits Live at The Moody Theater         Austin
# 25  Austin City Limits Live at The Moody Theater         Austin
# 69                       Whitewater Amphitheater  New Braunfels
# 52                    H-E-B Center at Cedar Park     Cedar Park
# 28                                Aztec Theatre     San Antonio
# 44                       Whitewater Amphitheater  New Braunfels
# 81                                   Zilker Park         Austin
# 74                  3TEN Austin City Limits Live         Austin
# 47  Austin City Limits Live at The Moody Theater         Austin
# 26                                Aztec Theatre     San Antonio
# 2   Austin City Limits Live at The Moody Theater         Austin
#
#    TM_venue_state TM_venue _lat TM_venue_long               TM_date  \
# 75             TX    29.4264514   -98.4903863  2021-11-14T01:00:00Z
# 57             TX   30.26536691   -97.7471222  2022-03-21T01:00:00Z
# 35             TX    30.5393195     -97.82448  2021-05-01T00:30:00Z
# 12             TX   30.26536691   -97.7471222  2021-06-13T00:00:00Z
# 3              TX   30.13310378  -97.64039993  2021-08-13T00:00:00Z
# 3              TX   30.26536691   -97.7471222  2021-04-12T01:00:00Z
# 54             TX      29.42597   -98.4428439  2021-10-13T01:00:00Z
# 64             TX    30.5393195     -97.82448  2021-06-27T01:00:00Z
# 27             TX   30.26536691   -97.7471222                    {}
# 10             TX   30.26536691   -97.7471222  2021-08-08T01:00:00Z
# 25             TX   30.26536691   -97.7471222  2022-08-06T01:00:00Z
# 69             TX     29.862013    -98.156969  2021-05-23T01:00:00Z
# 52             TX    30.5393195     -97.82448  2021-07-25T01:00:00Z
# 28             TX   29.42471628  -98.49110126  2021-11-06T00:30:00Z
# 44             TX     29.862013    -98.156969  2021-10-09T01:30:00Z
# 81             TX    30.2456728   -97.7688358                    {}
# 74             TX     30.265754    -97.747077  2021-07-19T01:30:00Z
# 47             TX   30.26536691   -97.7471222  2021-06-06T01:00:00Z
# 26             TX   29.42471628  -98.49110126  2021-10-25T23:00:00Z
# 2              TX   30.26536691   -97.7471222  2021-04-03T01:00:00Z
#
#         TM_timezone  ...      max     min    type_x primary segment  \
# 75  America/Chicago  ...    69.50   39.50  standard    True   Music
# 57  America/Chicago  ...    79.50   49.50  standard    True   Music
# 35  America/Chicago  ...    75.00   35.00  standard    True   Music
# 12  America/Chicago  ...    79.50   47.00  standard    True   Music
# 3   America/Chicago  ...   166.00   65.50  standard    True   Music
# 3   America/Chicago  ...    30.00   25.00  standard    True   Music
# 54  America/Chicago  ...   129.50   49.50  standard    True   Music
# 64  America/Chicago  ...   150.00   55.00  standard    True   Music
# 27  America/Chicago  ...   378.00  207.00  standard    True   Music
# 10  America/Chicago  ...    89.50   59.50  standard    True   Music
# 25  America/Chicago  ...   125.00   49.00  standard    True   Music
# 69  America/Chicago  ...    45.00   23.00  standard    True   Music
# 52  America/Chicago  ...    75.00   40.00  standard    True   Music
# 28  America/Chicago  ...    30.00   30.00  standard    True   Music
# 44  America/Chicago  ...  1536.00   48.00  standard    True   Music
# 81  America/Chicago  ...      NaN     NaN       NaN    True   Music
# 74  America/Chicago  ...    35.00   35.00  standard    True   Music
# 47  America/Chicago  ...    40.00   34.00  standard    True   Music
# 26  America/Chicago  ...    59.50   44.50  standard    True   Music
# 2   America/Chicago  ...    80.75   40.75  standard    True   Music
#
#           genre          subGenre  \
# 75        World             World
# 57        Blues             Blues
# 35          R&B               R&B
# 12         Rock  Alternative Rock
# 3          Rock               Pop
# 3          Rock               Pop
# 54        Metal          Nu-Metal
# 64          R&B               R&B
# 27         Rock  Alternative Rock
# 10         Rock               Pop
# 25         Rock  Alternative Rock
# 69      Country           Country
# 52  Hip-Hop/Rap        French Rap
# 28         Rock               Pop
# 44      Country           Country
# 81    Undefined         Undefined
# 74         Jazz              Jazz
# 47         Rock               Pop
# 26         Rock  Alternative Rock
# 2          Rock               Pop
#
#                                               type_y  \
# 75    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 57    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 35    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 12    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 3     {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 3     {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 54    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 64    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 27    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 10    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 25    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 69    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 52    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 28    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 44    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 81  {'id': 'KZAyXgnZfZ7v7lt', 'name': 'Event Style'}
# 74    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 47    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 26    {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
# 2     {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'}
#
#                                               subType family
# 75  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 57  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 35  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 12  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 3   {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 3   {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 54  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 64  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 27  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 10  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 25  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 69  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 52  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 28  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 44  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 81   {'id': 'KZFzBErXgnZfZ7vA6E', 'name': 'Festival'}  False
# 74  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 47  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 26  {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
# 2   {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'}  False
#
# [20 rows x 27 columns]

# %%
tm_df.columns
# Out:
# Index([                'TM_id',               'TM_name',
#                    'TM_artist',              'TM_venue',
#                'TM_venue_city',        'TM_venue_state',
#                'TM_venue _lat',         'TM_venue_long',
#                      'TM_date',           'TM_timezone',
#        'TM_span_multiple_days', 'TM_presale_date_start',
#          'TM_presale_date_end',    'TM_sale_date_start',
#                  'TM_promoter',                       0,
#                     'currency',                   'max',
#                          'min',                'type_x',
#                      'primary',               'segment',
#                        'genre',              'subGenre',
#                       'type_y',               'subType',
#                       'family'],
#       dtype='object')

# %%
#Conert data to .csv
tm_df.to_csv('tm_events_040121_050121')
